# %% [markdown]
# # Analysis
#
# Some **notes** before the code.

# %%
x = 6 * 7
print('hello')
print('world')
x
# Out:
# hello
# world
# 42

# %%
1/0
# Out:
# ---
# ZeroDivisionError: division by zero
